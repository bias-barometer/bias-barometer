# %% [markdown]
# ## Training and evaluating FastText Embeddings
# This notebook provides a quick example for training and evaluating FastText embeddings.

# %% [markdown]
# ### Training FastText embeddings
# **Note: This is only a quick example and more care should be put in collecting good training data!**
#
# Also, note that for each run, some random initialization happens by FastText.

# %% [markdown]
# #### Load and prepare datasets

# %%
import pandas as pd
bug_balanced = pd.read_csv("../data/datasets/balanced_BUG.csv")
bug_balanced
# Out:
#        Unnamed: 0                                      sentence_text
# 0               0  Notice of contact depends on the time the infe...  \
# 1               1  Hepaprotective agent glycyrrhizinate was added...
# 2               2  So yes , that was humbling . " Addressing the ...
# 3               3  Following previous works based on classical pr...
# 4               4  The second aspect is the agent neighborhood ! ...
# ...           ...                                                ...
# 25499       25499  A criminal investigator , specializing in digi...
# 25500       25500  However , the person who worked on them , Illu...
# 25501       25501  The student , Bob Anderson , had started a mag...
# 25502       25502  The film is set in a village in the Indian pro...
# 25503       25503  Parker said many viewers thought the character...
#
#                                                   tokens    profession    g
# 0      ['Notice', 'of', 'contact', 'depends', 'on', '...        person  her  \
# 1      ['Hepaprotective', 'agent', 'glycyrrhizinate',...         agent  her
# 2      ['So', 'yes', ',', 'that', 'was', 'humbling', ...     assistant  her
# 3      ['Following', 'previous', 'works', 'based', 'o...         agent  her
# 4      ['The', 'second', 'aspect', 'is', 'the', 'agen...         agent  her
# ...                                                  ...           ...  ...
# 25499  ['A', 'criminal', 'investigator', ',', 'specia...  investigator  his
# 25500  ['However', ',', 'the', 'person', 'who', 'work...        person   he
# 25501  ['The', 'student', ',', 'Bob', 'Anderson', ','...       student   he
# 25502  ['The', 'film', 'is', 'set', 'in', 'a', 'villa...       teacher  his
# 25503  ['Parker', 'said', 'many', 'viewers', 'thought...        person   he
#
#        profession_first_index  g_first_index predicted gender  stereotype
# 0                           9             13           female           1  \
# 1                           1              6           female           1
# 2                          17             21           female           1
# 3                          23             30           female           1
# 4                           5             20           female           1
# ...                       ...            ...              ...         ...
# 25499                       2             10             male          -1
# 25500                       3             13             male          -1
# 25501                       1             17             male          -1
# 25502                      42             47             male          -1
# 25503                      10             14             male          -1
#
#        distance  num_of_pronouns     corpus  data_index
# 0             4                1    covid19           1
# 1             5                1    covid19           1
# 2             4                3    covid19           1
# 3             7                1    covid19           1
# 4            15                1    covid19          14
# ...         ...              ...        ...         ...
# 25499         8                1     pubmed          17
# 25500        10                2  wikipedia           4
# 25501        16                1  wikipedia          11
# 25502         5                1  wikipedia          20
# 25503         4                3  wikipedia           4
#
# [25504 rows x 13 columns]

# %%
bug_unbalanced = pd.read_csv("../data/datasets/full_BUG.csv", nrows=len(bug_balanced))
bug_unbalanced
# Out:
#        Unnamed: 0                                      sentence_text
# 0               0  Patient number 2 was isolated with his wife th...  \
# 1               1  Five days post admission to the CCU , the pati...
# 2               2  One patient whose fascial layers were closed i...
# 3               3  The patient was discharged 18 days after his a...
# 4               4  PATIENT CONCERNS A 24 year-old male was referr...
# ...           ...                                                ...
# 25499       25499  The patient subsequently admitted that he had ...
# 25500       25500  One patient recalled that he had felt pain and...
# 25501       25501  Although healing of the periapical lesion occu...
# 25502       25502  This month , farmer Joe Stanley describes why ...
# 25503       25503  The author of this paper discusses how he has ...
#
#                                                   tokens profession    g
# 0      ['Patient', 'number', '2', 'was', 'isolated', ...    Patient  his  \
# 1      ['Five', 'days', 'post', 'admission', 'to', 't...    patient  his
# 2      ['One', 'patient', 'whose', 'fascial', 'layers...    patient  her
# 3      ['The', 'patient', 'was', 'discharged', '18', ...    patient  his
# 4      ['PATIENT', 'CONCERNS', 'A', '24', 'year', '-'...    PATIENT  his
# ...                                                  ...        ...  ...
# 25499  ['The', 'patient', 'subsequently', 'admitted',...    patient   he
# 25500  ['One', 'patient', 'recalled', 'that', 'he', '...    patient   he
# 25501  ['Although', 'healing', 'of', 'the', 'periapic...    patient   he
# 25502  ['This', 'month', ',', 'farmer', 'Joe', 'Stanl...     farmer   he
# 25503  ['The', 'author', 'of', 'this', 'paper', 'disc...     author   he
#
#        profession_first_index  g_first_index predicted gender  stereotype
# 0                           0              6             male           0  \
# 1                           9             14             male           0
# 2                           1             15           female           0
# 3                           1              7             male           0
# 4                           0             12             male           0
# ...                       ...            ...              ...         ...
# 25499                       1              5             male           0
# 25500                       1              4             male           0
# 25501                       9             12             male           0
# 25502                       3              8             male           1
# 25503                       1              7             male          -1
#
#        distance  num_of_pronouns   corpus  data_index
# 0             6                1  covid19           1
# 1             5                1  covid19           1
# 2            14                1  covid19           1
# 3             6                1  covid19           1
# 4            10                1  covid19           1
# ...         ...              ...      ...         ...
# 25499         4                2   pubmed           4
# 25500         3                1   pubmed           4
# 25501         3                1   pubmed           4
# 25502         5                2   pubmed           4
# 25503         6                1   pubmed           4
#
# [25504 rows x 13 columns]

# %%
from datasets import load_dataset

# Load a book corpus dataset as base dataset
book_dataset = load_dataset("bookcorpus", split="train[:25504]")
book_text = [sentence for sentence in book_dataset["text"]]
book_dataset.to_pandas().head()
# Out:
# Found cached dataset bookcorpus (/Users/oskarvanderwal/.cache/huggingface/datasets/bookcorpus/plain_text/1.0.0/eddee3cae1cc263a431aa98207d4d27fd8a73b0a9742f692af0e6c65afa4d75f)
#                                                 text
# 0  usually , he would be tearing around the livin...
# 1  but just one look at a minion sent him practic...
# 2  that had been megan 's plan when she got him d...
# 3  he 'd seen the movie almost by mistake , consi...
# 4  she liked to think being surrounded by adults ...

# %%
# Create three text files as training data

with open("book.txt", 'w') as f:
    f.write("\n".join(book_text))

with open("unbalanced.txt", 'w') as f:
    f.write("\n".join(bug_unbalanced["sentence_text"].tolist()))

with open("balanced.txt", 'w') as f:
    f.write("\n".join(bug_balanced["sentence_text"].tolist()))

# %% [markdown]
# #### Train and save FastText embeddings

# %%
import fasttext

model_book = fasttext.train_unsupervised('book.txt', model='skipgram')
model_balanced = fasttext.train_unsupervised('balanced.txt', model='skipgram')
model_unbalanced = fasttext.train_unsupervised('unbalanced.txt', model='skipgram')
# Out:
# Read 0M words
# Number of words:  3834
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  285872 lr:  0.000000 avg.loss:  2.545298 ETA:   0h 0m 0s
# Read 0M words
# Number of words:  11010
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  139062 lr:  0.000000 avg.loss:  2.409050 ETA:   0h 0m 0s
# Read 0M words
# Number of words:  8819
# Number of labels: 0
# Progress: 100.0% words/sec/thread:  141782 lr:  0.000000 avg.loss:  2.383835 ETA:   0h 0m 0s

# %%
model_balanced.words[:10]
# Out:
# [',', 'the', '</s>', '.', 'and', 'of', 'a', '"', 'in', 'to']

# %%
model_balanced.save_model("fasttext_balanced.bin")
model_unbalanced.save_model("fasttext_unbalanced.bin")
model_book.save_model("fasttext_book.bin")

# %% [markdown]
# ### Evaluating FastText embeddings

# %%
from biasbarometer.models import FastTextEmbeddingsModel
from biasbarometer.barometers import AutoBarometer

# Operationalize the barometer using Dutch word lists this time
barometer = AutoBarometer.from_spec("direction", wordpairs="../data/wordlists/man_vs_woman.csv", target="../data/wordlists/occupations.txt")

results = {}

for m in ["balanced", "unbalanced", "book"]:
    embeddings = FastTextEmbeddingsModel(f"fasttext_{m}.bin", device="cpu").embeddings

    # Run the bias evaluation
    barometer.evaluate(embeddings)

    results[m] = barometer.results
    print(m, "score: ", barometer.results["score"])
# Out:
# balanced score:  0.29308185810040926
# unbalanced score:  0.46710792957696246
# book score:  0.27703325134969253

# %% [markdown]
# #### Balanced

# %%
df = results["balanced"]["bias_df"]
df[df["category"]=="target"]
# Out:
#              word     score category
# 0         manager  0.728590   target
# 1           clerk  0.621153   target
# 2         officer  0.378479   target
# 3       secretary  0.347692   target
# 4   administrator  0.334812   target
# 5       architect  0.326884   target
# 6        engineer  0.263920   target
# 7       bartender  0.262998   target
# 8          broker  0.212344   target
# 9         cashier  0.208459   target
# 10        auditor  0.182095   target
# 11        plumber  0.177994   target
# 13    electrician  0.125414   target
# 14        planner  0.121913   target
# 15     instructor  0.074779   target
# 22      inspector  0.029416   target
# 23        painter  0.018301   target
# 24      machinist  0.001210   target
# 25     technician -0.018869   target
# 26         lawyer -0.029278   target
# 27     supervisor -0.031662   target
# 28   investigator -0.034644   target
# 29      carpenter -0.056248   target
# 31       mechanic -0.071204   target
# 32        advisor -0.075781   target
# 33     dispatcher -0.085889   target
# 34        janitor -0.129986   target
# 35          baker -0.130460   target
# 36      librarian -0.130652   target
# 38           chef -0.149665   target
# 39       examiner -0.154020   target
# 40      counselor -0.189395   target
# 41        surgeon -0.190529   target
# 42   practitioner -0.200523   target
# 43    hairdresser -0.217204   target
# 44     accountant -0.256143   target
# 45     programmer -0.285022   target
# 46        teacher -0.318096   target
# 47         worker -0.330642   target
# 48     pharmacist -0.352289   target
# 49   receptionist -0.368754   target
# 50         doctor -0.374675   target
# 51      scientist -0.418026   target
# 52   veterinarian -0.446062   target
# 53      therapist -0.515694   target
# 54     specialist -0.516842   target
# 55      physician -0.546423   target
# 56        chemist -0.567362   target
# 65    pathologist -0.758685   target
# 66   psychologist -0.820880   target
# 68       educator -0.886085   target
# 69          nurse -1.166115   target

# %% [markdown]
# #### Unbalanced

# %%
df = results["unbalanced"]["bias_df"]
df[df["category"]=="target"]
# Out:
#              word     score category
# 0         surgeon  0.342226   target
# 1       scientist  0.256169   target
# 2     pathologist  0.155013   target
# 3         auditor -0.000578   target
# 11   investigator -0.080511   target
# 12      librarian -0.082590   target
# 14          clerk -0.152537   target
# 15      architect -0.155174   target
# 16      bartender -0.204451   target
# 17         broker -0.219188   target
# 18          baker -0.246153   target
# 19        cashier -0.251913   target
# 20        chemist -0.266906   target
# 21        plumber -0.273736   target
# 22     technician -0.293984   target
# 25    hairdresser -0.307294   target
# 26     dispatcher -0.319278   target
# 27         lawyer -0.324162   target
# 28           chef -0.334986   target
# 29     supervisor -0.362635   target
# 30       examiner -0.377906   target
# 31         worker -0.378809   target
# 32    electrician -0.382918   target
# 33       mechanic -0.390986   target
# 34   receptionist -0.398726   target
# 35     instructor -0.402914   target
# 36      machinist -0.410175   target
# 37      inspector -0.413935   target
# 38        janitor -0.417994   target
# 39        painter -0.423016   target
# 40   veterinarian -0.442180   target
# 41      secretary -0.451688   target
# 42     accountant -0.455589   target
# 43        officer -0.458262   target
# 44       engineer -0.470090   target
# 45      carpenter -0.479544   target
# 46      physician -0.534682   target
# 47   psychologist -0.558538   target
# 48         doctor -0.586208   target
# 50     specialist -0.632045   target
# 51        planner -0.674316   target
# 52        advisor -0.694073   target
# 53        manager -0.699788   target
# 55        teacher -0.732758   target
# 61       educator -0.773416   target
# 62   practitioner -0.829513   target
# 63      therapist -0.847512   target
# 64     pharmacist -0.865015   target
# 66  administrator -0.920607   target
# 67     programmer -0.964578   target
# 68          nurse -1.239254   target
# 69      counselor -1.353091   target
